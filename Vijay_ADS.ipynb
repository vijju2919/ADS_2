# %% [markdown]
#  #### Stundent Name: Vijay kumar Ramavath

# %% [markdown]
# #### Student ID:21031708

# %%
import pandas as pd
import matplotlib.pyplot as plt
import wbgapi as wb

# %%
wb.source.info()
# Out:
# id    name                                                                  code      concepts  lastupdated
# ----  --------------------------------------------------------------------  ------  ----------  -------------
# 1     Doing Business                                                        DBS              3  2021-08-18
# 2     World Development Indicators                                          WDI              3  2022-04-08
# 3     Worldwide Governance Indicators                                       WGI              3  2021-09-27
# 5     Subnational Malnutrition Database                                     SNM              3  2016-03-21
# 6     International Debt Statistics                                         IDS              4  2022-01-14
# 11    Africa Development Indicators                                         ADI              3  2013-02-22
# 12    Education Statistics                                                  EDS              3  2020-12-20
# ...

# %%
wb.series.info(q='arable')
# Out:
# id                 value
# -----------------  --------------------------------------------------------------
# AG.LND.ARBL.HA     Arable land (hectares)
# AG.LND.ARBL.HA.PC  Arable land (hectares per person)
# AG.LND.ARBL.ZS     Arable land (% of land area)
# AG.LND.TRAC.ZS     Agricultural machinery, tractors per 100 sq. km of arable land
#                    4 elements

# %%
wb.series.info(q='forest')
# Out:
# id                 value
# -----------------  ------------------------------------------------------------------------------
# AG.LND.FRST.K2     Forest area (sq. km)
# AG.LND.FRST.ZS     Forest area (% of land area)
# NV.AGR.EMPL.KD     Agriculture, forestry, and fishing, value added per worker (constant 2015 US$)
# NV.AGR.TOTL.CD     Agriculture, forestry, and fishing, value added (current US$)
# NV.AGR.TOTL.CN     Agriculture, forestry, and fishing, value added (current LCU)
# NV.AGR.TOTL.KD     Agriculture, forestry, and fishing, value added (constant 2015 US$)
# NV.AGR.TOTL.KD.ZG  Agriculture, forestry, and fishing, value added (annual % growth)
# NV.AGR.TOTL.KN     Agriculture, forestry, and fishing, value added (constant LCU)
# NV.AGR.TOTL.ZS     Agriculture, forestry, and fishing, value added (% of GDP)
# NY.ADJ.DFOR.CD     Adjusted savings: net forest depletion (current US$)
# NY.ADJ.DFOR.GN.ZS  Adjusted savings: net forest depletion (% of GNI)
# ...

# %%
Arable= wb.data.DataFrame('AG.LND.ARBL.HA', wb.region.members('EMU'))

# %%
Arable
# Out:
#          YR1960      YR1961      YR1962      YR1963      YR1964      YR1965  \
# economy
# AUT         NaN   1689000.0   1681000.0   1656000.0   1657000.0   1660000.0
# BEL         NaN   1007000.0   1004000.0   1001000.0    998000.0    996000.0
# CYP         NaN    329000.0    327000.0    325000.0    323000.0    322000.0
# DEU         NaN  12220000.0  12185000.0  12165000.0  12161000.0  12153000.0
# ESP         NaN  16246000.0  16296000.0  16205000.0  15919000.0  15966000.0
# EST         NaN         NaN         NaN         NaN         NaN         NaN
# FIN         NaN   2664700.0   2679100.0   2695500.0   2709600.0   2720500.0
# FRA         NaN  19606000.0  19530000.0  19455000.0  19078000.0  18796000.0
# GRC         NaN   2794000.0   2863000.0   3057000.0   3001000.0   2991000.0
# IRL         NaN   1590000.0   1567000.0   1561000.0   1526000.0   1492000.0
# ITA         NaN  12862000.0  12795000.0  12674000.0  12598000.0  12524000.0
# ...

# %%
Forest= wb.data.DataFrame('AG.LND.FRST.K2', wb.region.members('EMU'))

# %%
Forest
# Out:
#          YR1960  YR1961  YR1962  YR1963  YR1964  YR1965  YR1966  YR1967  \
# economy
# AUT         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# BEL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# CYP         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# DEU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ESP         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# EST         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# FIN         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# FRA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# GRC         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# IRL         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ITA         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# LTU         NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...

# %%
indicator=['AG.LND.ARBL.HA','AG.LND.FRST.K2']
country=['GBR','USA','IND']
my_dataframe=wb.data.DataFrame(indicator,country, mrv=5)

# %%
my_dataframe
# Out:
#                              YR2016       YR2017       YR2018     YR2019  \
# economy series
# GBR     AG.LND.ARBL.HA    6026010.5    6082879.4    6037787.4        NaN
#         AG.LND.FRST.K2      31590.0      31640.0      31730.0    31820.0
# IND     AG.LND.ARBL.HA  156416000.0  156416000.0  156416000.0        NaN
#         AG.LND.FRST.K2     710944.0     713608.0     716272.0   718936.0
# USA     AG.LND.ARBL.HA  157191000.0  157736800.0  157736800.0        NaN
#         AG.LND.FRST.K2    3100950.0    3097950.0    3097950.0  3097950.0
#
#                            YR2020
# economy series
# GBR     AG.LND.ARBL.HA        NaN
#         AG.LND.FRST.K2    31900.0
# IND     AG.LND.ARBL.HA        NaN
#         AG.LND.FRST.K2   721600.0
# USA     AG.LND.ARBL.HA        NaN
#         AG.LND.FRST.K2  3097950.0

# %%
De = wb.data.DataFrame('AG.LND.FRST.K2',
                      ['GBR','USA','IND'],
                      time=range(2011,2020,1))

# %%
De
# Out:
#             YR2011     YR2012     YR2013     YR2014     YR2015     YR2016  \
# economy
# GBR        30782.0    30974.0    31166.0    31358.0    31550.0    31590.0
# IND       697624.0   700288.0   702952.0   705616.0   708280.0   710944.0
# USA      3089950.0  3092700.0  3095450.0  3098200.0  3100950.0  3100950.0
#
#             YR2017     YR2018     YR2019
# economy
# GBR        31640.0    31730.0    31820.0
# IND       713608.0   716272.0   718936.0
# USA      3097950.0  3097950.0  3097950.0

# %%
De.describe()
# Out:
#              YR2011        YR2012        YR2013        YR2014        YR2015  \
# count  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# mean   1.272785e+06  1.274654e+06  1.276523e+06  1.278391e+06  1.280260e+06
# std    1.608644e+06  1.609647e+06  1.610651e+06  1.611656e+06  1.612661e+06
# min    3.078200e+04  3.097400e+04  3.116600e+04  3.135800e+04  3.155000e+04
# 25%    3.642030e+05  3.656310e+05  3.670590e+05  3.684870e+05  3.699150e+05
# 50%    6.976240e+05  7.002880e+05  7.029520e+05  7.056160e+05  7.082800e+05
# 75%    1.893787e+06  1.896494e+06  1.899201e+06  1.901908e+06  1.904615e+06
# max    3.089950e+06  3.092700e+06  3.095450e+06  3.098200e+06  3.100950e+06
#
#              YR2016        YR2017        YR2018        YR2019
# count  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# mean   1.281161e+06  1.281066e+06  1.281984e+06  1.282902e+06
# std    1.612174e+06  1.609991e+06  1.609487e+06  1.608985e+06
# ...

# %%
ar= wb.data.DataFrame('AG.LND.ARBL.HA',
                      ['GBR','USA','IND'],
                      time=range(2011,2020,1))

# %%
ar
# Out:
#               YR2011       YR2012       YR2013       YR2014       YR2015  \
# economy
# GBR        6062000.0    6212000.0    6265400.0    6233500.0    6011000.0
# IND      156979000.0  156546000.0  156442000.0  156463000.0  156416000.0
# USA      156362000.0  155007500.0  155553400.0  156099300.0  156645100.0
#
#               YR2016       YR2017       YR2018  YR2019
# economy
# GBR        6026010.5    6082879.4    6037787.4     NaN
# IND      156416000.0  156416000.0  156416000.0     NaN
# USA      157191000.0  157736800.0  157736800.0     NaN

# %%
ar.describe()
# Out:
#              YR2011        YR2012        YR2013        YR2014        YR2015  \
# count  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00  3.000000e+00
# mean   1.064677e+08  1.059218e+08  1.060869e+08  1.062653e+08  1.063574e+08
# std    8.695441e+07  8.635467e+07  8.644913e+07  8.663024e+07  8.690258e+07
# min    6.062000e+06  6.212000e+06  6.265400e+06  6.233500e+06  6.011000e+06
# 25%    8.121200e+07  8.060975e+07  8.090940e+07  8.116640e+07  8.121350e+07
# 50%    1.563620e+08  1.550075e+08  1.555534e+08  1.560993e+08  1.564160e+08
# 75%    1.566705e+08  1.557768e+08  1.559977e+08  1.562812e+08  1.565306e+08
# max    1.569790e+08  1.565460e+08  1.564420e+08  1.564630e+08  1.566451e+08
#
#              YR2016        YR2017        YR2018  YR2019
# count  3.000000e+00  3.000000e+00  3.000000e+00     0.0
# mean   1.065443e+08  1.067452e+08  1.067302e+08     NaN
# std    8.705229e+07  8.717865e+07  8.720468e+07     NaN
# min    6.026010e+06  6.082879e+06  6.037787e+06     NaN
# ...

# %%
De.hist(bins=50, figsize=(20, 15))
plt.savefig('numeric_attributes.png')
plt.show()

# %%
ar.hist(bins=50, figsize=(20, 10))
plt.savefig('numeric_attributes.png')
plt.show()

# %%
wb.data.DataFrame('AG.LND.ARBL.HA',
                      ['GBR','USA','IND'],
                      time=range(2011,2020,1)).T.plot();

# %%
wb.data.DataFrame('AG.LND.FRST.K2',
                      ['GBR','USA','IND'],
                      time=range(2011,2020,1)).T.plot();
